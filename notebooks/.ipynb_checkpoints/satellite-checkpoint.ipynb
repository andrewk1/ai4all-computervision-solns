# %% [markdown]
# # Hands-On Research #1
#
# ## Exploring Satellite Data

# %%
# %load_ext autoreload
# %autoreload 2

from utils.satellite_util import *
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# /Users/aqua/miniconda3/envs/ai4all/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ### Displaying Single Satellite Images
#
# We've provided a function for visualizing satellite data. Run the next block to "define" the function so that python knows that it exists. Next, "call" the function with different arguments and see what images you get.
#
# You can go to [Google Maps](https://www.google.com/maps/) and click on different points around the world to reveal its coordinates in lantitute and longitude. Try finding some interesting places, and downloading images with "show_satellite_image" in Python!

# %%
"""
This function (show_satellite_image) "wraps" around a function for downloading images
(download_img) but also uses the library "plt" to display the image you downloaded.
"""
def show_satellite_image(latitude, longitude, zoom=16, width=224, height=224):
    X = download_img(latitude,longitude,zoom,width,height, save=False)
    plt.imshow(X)
    plt.show()
    
"""
Call show_satellite_image here. Try experimenting with different values for the arguments!
"""
show_satellite_image(2.211632, 40.873421, zoom=16, width=224, height=224)

# %% [markdown]
# For this project, we'll be working to map out which locations have high poverty around the country of **Uganda**. You can print out a list of coordinates for sites around Uganda by running the cell below. **Try** entering some of these into your show_satellite_image function to see how they look:

# %%
print_coordinates()
# Out:
# site 0: 1.399869, 32.256496
# site 1: 0.270254, 31.648449
# site 2: 2.211636, 32.873421
# site 3: 0.940079, 30.811918
# site 4: 2.028908, 33.590748
# site 5: 0.413775, 31.237961
# site 6: -0.105038, 30.264219
# site 7: 0.389507, 32.839104
# site 8: 0.686091, 31.266586
# site 9: 1.016565, 33.32798
# site 10: 0.644933, 33.712639
# site 11: 2.21651, 32.889805
# site 12: 0.257018, 32.57933
# site 13: 0.423703, 33.612171
# site 14: 3.498156, 34.130035
# site 15: 1.581441, 32.838669
# site 16: 0.16093, 32.552933
# site 17: 2.913344, 32.173874
# site 18: 3.442528, 30.945656
# site 19: -0.503361, 31.61607
# site 20: 2.311968, 33.009991
# site 21: 0.36772, 32.623959
# site 22: 2.542388, 32.327698
# site 23: 0.869543, 34.381268
# site 24: 0.326391, 32.555145
# site 25: 0.366758, 32.592381
# site 26: 0.602689, 33.707912
# site 27: 2.837233, 32.530605
# site 28: 1.700414, 33.688522
# site 29: 1.694317, 31.711855
# site 30: -0.120474, 31.879969
# site 31: 2.295686, 33.007851
# site 32: 1.120547, 34.054668
# site 33: -0.603494, 29.99411
# site 34: 2.600708, 32.850159
# site 35: 2.83684, 32.407825
# site 36: 0.822012, 30.792131
# site 37: 0.630705, 31.787724
# site 38: 0.423023, 33.144741
# site 39: 0.390593, 32.521591
# site 40: -0.539219, 30.705593
# site 41: -0.920324, 29.801229
# site 42: 2.505306, 32.383907
# site 43: 2.356898, 31.417545
# site 44: 0.326054, 32.510406
# site 45: 1.23299, 33.331226
# site 46: 0.513224, 33.417709
# site 47: 0.696242, 34.109386
# site 48: 0.589527, 32.623108
# site 49: 2.480794, 33.063114
# site 50: 1.445573, 33.481636
# site 51: -1.255216, 30.05682
# site 52: 2.395847, 32.513023
# site 53: 1.740958, 33.58334
# site 54: 1.525771, 33.550385
# site 55: 2.25625, 32.872898
# site 56: 0.389081, 30.486662
# site 57: 2.227439, 32.261585
# site 58: 0.712145, 32.52943
# site 59: 1.256083, 30.810326
# site 60: 2.584571, 30.935251
# site 156: 0.295155, 32.5854
# site 157: 1.766053, 33.023891
# site 158: 1.514885, 32.101482
# site 159: 0.362534, 32.574726
# site 160: 2.775307, 32.280388
# site 161: 3.244452, 31.158716
# site 162: 1.968198, 32.568344
# site 163: 1.060103, 33.010223
# site 164: 0.767358, 32.525814
# site 165: 2.394807, 31.126745
# site 166: 0.447067, 30.165287
# site 167: 1.374773, 34.301998
# site 168: 2.208691, 32.881786
# site 169: 2.330128, 33.039772
# site 170: 0.391493, 32.979301
# site 171: 0.411849, 32.688755
# site 172: 0.422721, 33.202499
# site 173: 1.734961, 33.468559
# site 174: 2.292009, 32.719528
# site 175: -0.608761, 30.67223
# site 176: 2.761965, 32.332062
# site 177: 2.263628, 32.898376
# site 178: -0.528356, 29.95418
# site 179: 2.128103, 33.572617
# site 180: 0.728758, 30.646589
# site 181: 0.887236, 30.693213
# site 182: 0.327525, 32.979481
# site 183: 3.309157, 32.873867
# site 184: 2.373681, 34.501106
# site 185: 0.329069, 32.640133
# site 186: 2.493781, 32.784485
# site 187: 0.66024, 33.241806
# site 188: 1.737862, 34.095272
# site 189: -0.522386, 31.355343
# site 190: 2.788371, 30.909168
# site 191: 1.867478, 32.79665
# site 192: 0.165164, 30.496117
# site 193: 2.496691, 30.875835
# site 194: 0.657477, 34.158772
# site 195: 0.625763, 33.288773
# site 196: 1.561474, 33.306297
# site 197: 1.474652, 31.338894
# site 198: 1.312257, 33.834137
# site 199: 2.960176, 32.261124

# %% [markdown]
# ### Download Images Automatically
#
# Entering in latitudes and longitudes by hand is tedious. Instead, we want to write a script to automatically go over the entries and download all the images we need.

# %%
"""
Can you write a loop that goes over all the locations and downloads images automatically?

HINT: You can use "print(coordinates)" to see what the coordinate list looks like. 
HINT: Make sure the "save" keyword for download_img is set to true!
HINT: You can check how download_img is called in the previous cell!
"""
def download_all_images(zoom=16, width=224, height=224):
    coordinates = get_coordinate_list(200)
    ## YOUR CODE HERE
    ## END YOUR CODE
    
"""
Call download_all_images() here
"""
download_all_images()

# %% [markdown]
# ### Predicting Poverty by Eye
#
# These images are the only information our AI program will receive before it can make judgments about where poverty occurs. Can you and I make good judgments with a similar amount of information? Run the cell below to start a simple quiz to find out!

# %%
"""
Call this script to begin a quiz on the satellite data you downloaded
"""
x, t = start_quiz()
# Out:
# Guess which areas have high poverty. Please enter your answers as a comma separated list
# Example: 0, 1, 2
# 3, 4, 5

# %% [markdown]
# ### Grade Yourself
#
# Once you've finished the quiz, run the next cell to find out how you did. Images shown in green are ones you got right, images are read are ones you got wrong.

# %%
"""
Call this script to reveal the answers
"""
compute_results(x, t)
# Out:
# y true vs y pred
# 0
# 0
# y true vs y pred
# 1
# 0
# y true vs y pred
# 1
# 0
# y true vs y pred
# 0
# 0
# y true vs y pred
# 0
# 0
# y true vs y pred
# 0
# 0
# y true vs y pred
# 0
# 1
# y true vs y pred
# 1
# 0
# y true vs y pred
# 1
# 0
# y true vs y pred
# 1
# 0
# ['3', '4', '5']
# {'0': 0.0, '5': 1.0, '1': 1.0, '6': 0.0, '2': 0.0, '7': 0.0, '3': 0.0, '8': 1.0, '4': 1.0, '9': 1.0}
# [0.0, 1.0, 1.0]
# Your accuracy was: 60.0%
